# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 16, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
data = pd.read_csv("C:/Users/Przemyslaw/Downloads/Zeszyt1.csv")

# %%
data
# Out:
#     m [j] ? [j] m2 [j2]  Unnamed: 3 m [j].1 ? [j].1 m2 [j2].1
# 0   -0,38  1,56    2,57         NaN   -0,44    1,10      1,39
# 1    -0,4  1,59    2,69         NaN   -0,41    1,09      1,35
# 2   -0,34  1,58    2,62         NaN   -0,36    1,11      1,37
# 3   -0,33  1,59    2,62         NaN   -0,45    1,07      1,34
# 4   -0,34  1,57    2,58         NaN   -0,35    1,10      1,34
# ..    ...   ...     ...         ...     ...     ...       ...
# 95   -0,3  1,62     2,7         NaN   -0,35    1,09      1,30
# 96   -0,5  1,58    2,76         NaN   -0,38    1,13      1,42
# 97  -0,41  1,62    2,78         NaN   -0,41    1,09      1,36
# 98  -0,37  1,66    2,89         NaN   -0,40    1,05      1,25
# 99  -0,42  1,59    2,72         NaN   -0,40    1,08      1,33
#
# [100 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['m [j]', '? [j]', 'm2 [j2]', 'Unnamed: 3', 'm [j].1', '? [j].1',
#        'm2 [j2].1'],
#       dtype='object')

# %%
data["σ [j].1"] = data["? [j].1"]

# %%
data["σ [j]"]
# Out:
# 0     1,56
# 1     1,59
# 2     1,58
# 3     1,59
# 4     1,57
#       ...
# 95    1,62
# 96    1,58
# 97    1,62
# 98    1,66
# 99    1,59
# Name: σ [j], Length: 100, dtype: object

# %%
data["? [j]"].str.replace(',',".").astype(float).value_counts(bins=4)
# Out:
# (1.54, 1.58]     45
# (1.62, 1.66]     27
# (1.58, 1.62]     25
# (1.499, 1.54]     3
# Name: ? [j], dtype: int64

# %%
sns.histplot(data["m2 [j2]"].str.replace(',',".").astype(float), stat="probability", bins=5, kde=True)
# Out:
# <AxesSubplot:xlabel='m2 [j2]', ylabel='Probability'>

# %%
data["m [j]"].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-7e65664e0265> in <module>
# ----> 1 data["m [j]"].count(-0.38)
#
# c:\Users\Przemyslaw\Projects\AirQualityPrediction\.venv\lib\site-packages\pandas\core\series.py in count(self, level)
#    1770             level = self.index._get_level_number(level)
#    1771
# -> 1772         lev = self.index.levels[level]
#    1773         level_codes = np.array(self.index.codes[level], subok=False, copy=True)
#    1774
#
# AttributeError: 'RangeIndex' object has no attribute 'levels'

# %%
plt.hist(data["m [j]"].to_numpy(), bins=[-0.38,-0.44], density=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-d0c9c88e488b> in <module>
# ----> 1 plt.hist(data["m [j]"].to_numpy(), bins=[-0.38,-0.44], density=True)
#
# c:\Users\Przemyslaw\Projects\AirQualityPrediction\.venv\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2666         orientation='vertical', rwidth=None, log=False, color=None,
#    2667         label=None, stacked=False, *, data=None, **kwargs):
# -> 2668     return gca().hist(
#    2669         x, bins=bins, range=range, density=density, weights=weights,
#    2670         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# c:\Users\Przemyslaw\Projects\AirQualityPrediction\.venv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
